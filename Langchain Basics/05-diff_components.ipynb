# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = "true"
os.environ['LANGCHAIN_PROJECT'] = "Getting-Started"

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = "gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x0000025EB43D9C10> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000025EB43FBAA0> root_client=<openai.OpenAI object at 0x0000025EB115F8C0> root_async_client=<openai.AsyncOpenAI object at 0x0000025EB0FCAB10> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get response from LLM

result = llm.invoke("What is Generative AI?")
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence technologies designed to generate new content. Unlike traditional AI, which focuses on classifying or predicting data, generative AI creates data that mimics real-world inputs. It can produce text, images, music, code, and other forms of content based on patterns learned from existing data. \n\nThe most prominent types of generative AI models are based on neural networks, particularly generative adversarial networks (GANs), variational autoencoders (VAEs), and transformer-based models. A well-known example of generative AI is OpenAI’s GPT (Generative Pre-trained Transformer) series, which can generate coherent and contextually relevant text.\n\nGenerative AI has numerous applications across industries, including content creation, design, entertainment, and even drug discovery. However, it also raises important ethical considerations, such as the potential for generating misleading information or infringing on intellectual property rights.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 185, 'prompt_tokens': 13, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_80956533cb', 'id': 'chatcmpl-C9UJrW2Co7B3nkz75E8Qx0Bv2enJW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--0ed29bc3-aedb-4fea-a9de-98d93672f005-0' usage_metadata={'input_tokens': 13, 'output_tokens': 185, 'total_tokens': 198, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(result.content)
# Out:
# Generative AI refers to a subset of artificial intelligence technologies designed to generate new content. Unlike traditional AI, which focuses on classifying or predicting data, generative AI creates data that mimics real-world inputs. It can produce text, images, music, code, and other forms of content based on patterns learned from existing data.
#
# The most prominent types of generative AI models are based on neural networks, particularly generative adversarial networks (GANs), variational autoencoders (VAEs), and transformer-based models. A well-known example of generative AI is OpenAI’s GPT (Generative Pre-trained Transformer) series, which can generate coherent and contextually relevant text.
#
# Generative AI has numerous applications across industries, including content creation, design, entertainment, and even drug discovery. However, it also raises important ethical considerations, such as the potential for generating misleading information or infringing on intellectual property rights.

# %%
## ChatPromptTempelate
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an Expert AI engineer. Provide the answers based on the questios."),
        ("user", "{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an Expert AI engineer. Provide the answers based on the questios.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## Chains
chain = prompt | llm 

response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is an integrated suite of tools and capabilities designed to enhance and optimize the development and deployment of applications leveraging large language models (LLMs). It extends the functionality of the Langchain framework, which is used for building applications powered by LLMs and other AI models. Langsmith provides developers with features for monitoring, evaluating, debugging, and improving their language model applications.\n\nKey features of Langsmith include:\n\n1. **Monitoring and Observability:** Langsmith offers tools to monitor the behavior of your language models in real time, enabling developers to track usage, performance, and detect anomalies.\n\n2. **Evaluation and Testing:** Langsmith facilitates comprehensive testing of language models by providing tools to evaluate their outputs systematically. This can include performance benchmarks and metrics to ensure models meet desired performance standards.\n\n3. **Debugging:** With Langsmith, developers can efficiently debug their models, pinpoint issues, and optimize their performance by examining how inputs are processed and outputs are generated.\n\n4. **Optimization:** Langsmith aids in refining prompts, optimizing configurations, and improving overall application workflow to achieve better results from language models.\n\nThese tools collectively empower developers to create more reliable, efficient, and intelligent AI systems by refining how they interact with and manage language models.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 35, 'total_tokens': 282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_80956533cb', 'id': 'chatcmpl-C9UOPJQD1RckWFNOm9ONhPDdhkuQp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--8ac9a195-2d89-482f-85de-682ab7b89f59-0' usage_metadata={'input_tokens': 35, 'output_tokens': 247, 'total_tokens': 282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response.content)
# Out:
# Langsmith is an integrated suite of tools and capabilities designed to enhance and optimize the development and deployment of applications leveraging large language models (LLMs). It extends the functionality of the Langchain framework, which is used for building applications powered by LLMs and other AI models. Langsmith provides developers with features for monitoring, evaluating, debugging, and improving their language model applications.
#
# Key features of Langsmith include:
#
# 1. **Monitoring and Observability:** Langsmith offers tools to monitor the behavior of your language models in real time, enabling developers to track usage, performance, and detect anomalies.
#
# 2. **Evaluation and Testing:** Langsmith facilitates comprehensive testing of language models by providing tools to evaluate their outputs systematically. This can include performance benchmarks and metrics to ensure models meet desired performance standards.
#
# 3. **Debugging:** With Langsmith, developers can efficiently debug their models, pinpoint issues, and optimize their performance by examining how inputs are processed and outputs are generated.
#
# 4. **Optimization:** Langsmith aids in refining prompts, optimizing configurations, and improving overall application workflow to achieve better results from language models.
#
# These tools collectively empower developers to create more reliable, efficient, and intelligent AI systems by refining how they interact with and manage language models.

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a platform developed by LangChain that focuses on enhancing the development and deployment of applications that utilize large language models (LLMs) and AI workflows. It serves as a comprehensive tool for both debugging and monitoring these applications. Key features of Langsmith include:
#
# 1. **Seamless Deployment**: The platform provides a robust environment for deploying AI-powered applications, ensuring that they are production-ready.
#
# 2. **Debugging and Monitoring**: Langsmith offers advanced tools for monitoring the performance of LLMs, allowing developers to identify and troubleshoot issues efficiently.
#
# 3. **Experimentation**: It facilitates the testing of different prompt engineering strategies and LLM configurations, enabling developers to optimize their AI applications for better performance and accuracy.
#
# 4. **Integration with LangChain**: Langsmith is designed to work hand-in-hand with LangChain, providing deeper insight and control over how LLMs are used within applications.
#
# Langsmith is particularly useful for developers who require granular control over their AI models and those who need a reliable framework for maintaining and improving AI-driven applications.
